# %%
import pandas as pd
import numpy as nb
import seaborn as sns
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import nltk

# %%
DataFrame = pd.read_csv("/content/combined_dataset.csv")
DataFrame.tail(10)
# Out:
#                                                Reviews
# 449  سرعة عالية 200ميجا . . . . . . . . . . 🤍💚  #ال...
# 450  @ZainKSA  التذكره ايش صار عليها محد فيكم تكرم ...
# 451  سرعة عالية 200ميجا . . . . . . . . . . 🤍💚  #ال...
# 452                                               قويه
# 453  إنترنت لا محدود / سرعة 200 ميقا    .  . . .  #...
# 454  إنترنت لا محدود / سرعة 200 ميقا    .  . . .  #...
# 455  إنترنت لا محدود / سرعة 200 ميقا    .  . . .  #...
# 456  سرعة عالية 200ميجا . . . . . . . . . . 🤍💚  #ال...
# 457  سرعة عالية 200ميجا . . . . . . . . . . 🤍💚  #ال...
# 458  كيف اشترك فيها ؟ لان ما تطلع  لي بالتطبيق الا ...

# %%
DataFrame.shape
# Out:
# (459, 1)

# %% [markdown]
# ## Removing duplicate values

# %%
DataFrame2 = DataFrame.drop_duplicates()
DataFrame2.tail(10)
# Out:
#                                                Reviews
# 445                       سرعة عالية 200ميجا #ال5G_زين
# 446  @ZainKSA لو سمحت ممكن تردون ! شبكه البيت ماصار...
# 447  السلام عليكم كيف احول الشريحه الى فايف جي هل ف...
# 448  ليتكم تطورون التطبيق كتطبيق @stc_ksa وبرنامج و...
# 450  @ZainKSA  التذكره ايش صار عليها محد فيكم تكرم ...
# 452                                               قويه
# 453  إنترنت لا محدود / سرعة 200 ميقا    .  . . .  #...
# 455  إنترنت لا محدود / سرعة 200 ميقا    .  . . .  #...
# 456  سرعة عالية 200ميجا . . . . . . . . . . 🤍💚  #ال...
# 458  كيف اشترك فيها ؟ لان ما تطلع  لي بالتطبيق الا ...

# %%
DataFrame2.shape
# Out:
# (394, 1)

# %%
print(DataFrame2["Reviews"][453])
print(DataFrame2["Reviews"][455])
# Out:
# إنترنت لا محدود / سرعة 200 ميقا    .  . . .  #زين_السعودية . . .
# إنترنت لا محدود / سرعة 200 ميقا    .  . . .  #زين_السعودية . . . . .

# %% [markdown]
# Pre-pro

# %%
import aranorm

# %%
DataFrame2['Reviews'] = DataFrame2['Reviews'].fillna('').apply(aranorm.normalize_arabic_text)
# Out:
# <ipython-input-58-e6ea1d56dd45>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DataFrame2['Reviews'] = DataFrame2['Reviews'].fillna('').apply(aranorm.normalize_arabic_text)

# %%
DataFrame2.tail(10)
# Out:
#                                                Reviews
# 445                             سرعه عاليه ميجا ال زين
# 446  لو سمحت ممكن تردون شبكه البيت ماصار لها شهر بس...
# 447  السلام عليكم كيف احول الشريحه الي فايف جي هل ف...
# 448  ليتكم تطورون التطبيق كتطبيق وبرنامج ولاء مميز ...
# 450  التذكره ايش صار عليها محد فيكم تكرم تواصل معي ...
# 452                                               قويه
# 453             انترنت لا محدود سرعه ميقا زين السعوديه
# 455             انترنت لا محدود سرعه ميقا زين السعوديه
# 456     سرعه عاليه ميجا ال زين يارب وماخاب من قال يارب
# 458  كيف اشترك فيها لان ما تطلع لي بالتطبيق الا اذا...

# %%
DataFrame2 = DataFrame2.drop_duplicates()
DataFrame2.tail(10)
# Out:
#                                                Reviews
# 441                                     طريقه الاشتراك
# 444  ياخي لي ساعه ابي اجدد قبل موعد انتهي الباقه لا...
# 446  لو سمحت ممكن تردون شبكه البيت ماصار لها شهر بس...
# 447  السلام عليكم كيف احول الشريحه الي فايف جي هل ف...
# 448  ليتكم تطورون التطبيق كتطبيق وبرنامج ولاء مميز ...
# 450  التذكره ايش صار عليها محد فيكم تكرم تواصل معي ...
# 452                                               قويه
# 453             انترنت لا محدود سرعه ميقا زين السعوديه
# 456     سرعه عاليه ميجا ال زين يارب وماخاب من قال يارب
# 458  كيف اشترك فيها لان ما تطلع لي بالتطبيق الا اذا...

# %%
DataFrame2.shape
# Out:
# (387, 1)

# %%
print("Null values in the DataFrame:")
null_counts = DataFrame2.isnull().sum()
print(null_counts)
# Out:
# Null values in the DataFrame:
# Reviews    0
# dtype: int64

# %% [markdown]
# Getting Tokenize the tweet text

# %%
tokenizer = RegexpTokenizer(r'\w+')
DataFrame2["Reviews"] = DataFrame2["Reviews"].apply(tokenizer.tokenize)

# %%
DataFrame2["Reviews"].head(10)
# Out:
# 0    [كان, لي, تجربه, اكثر, من, راءعه, اليوم, في, ه...
# 1    [اسوء, خدمه, شركه, اتصالات, علي, المستوي, العر...
# 2    [اشكر, الموظفه, ضيء, علي, تعاملها, ورقيها, وخد...
# 3    [اسوا, نت, في, العالم, عانيت, مليون, مرررررا, ...
# 4    [الفرع, جدا, ممتاز, واشكر, الاخوات, الموظفات, ...
# 5    [ما, انصح, احد, يطلع, من, ذي, الشركه, شبكه, ال...
# 6    [الشباب, في, الفرع, قمه, في, التعامل, الشركه, ...
# 7    [تواصل, ضعيف, من, قبل, الموظفه, تركيز, الموظفه...
# 8    [ممتاز, والموظفه, اسلوبها, جدا, راقي, وسلسه, ف...
# 9      [بطء, جدا, جدا, جدا, الخبره, تكاد, شبه, معدومه]
# Name: Reviews, dtype: object

# %%
stopwords_list = stopwords.words('arabic')

# %%
stopwords_list
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
print(len(stopwords_list))
# Out:
# 754

# %%
listToStr = ' '.join([str(elem) for elem in stopwords_list])

# %%
listToStr
# Out:
# 'إذ إذا إذما إذن أف أقل أكثر ألا إلا التي الذي الذين اللاتي اللائي اللتان اللتيا اللتين اللذان اللذين اللواتي إلى إليك إليكم إليكما إليكن أم أما أما إما أن إن إنا أنا أنت أنتم أنتما أنتن إنما إنه أنى أنى آه آها أو أولاء أولئك أوه آي أي أيها إي أين أين أينما إيه بخ بس بعد بعض بك بكم بكم بكما بكن بل بلى بما بماذا بمن بنا به بها بهم بهما بهن بي بين بيد تلك تلكم تلكما ته تي تين تينك ثم ثمة حاشا حبذا حتى حيث حيثما حين خلا دون ذا ذات ذاك ذان ذانك ذلك ذلكم ذلكما ذلكن ذه ذو ذوا ذواتا ذواتي ذي ذين ذينك ريث سوف سوى شتان عدا عسى عل على عليك عليه عما عن عند غير فإذا فإن فلا فمن في فيم فيما فيه فيها قد كأن كأنما كأي كأين كذا كذلك كل كلا كلاهما كلتا كلما كليكما كليهما كم كم كما كي كيت كيف كيفما لا لاسيما لدى لست لستم لستما لستن لسن لسنا لعل لك لكم لكما لكن لكنما لكي لكيلا لم لما لن لنا له لها لهم لهما لهن لو لولا لوما لي لئن ليت ليس ليسا ليست ليستا ليسوا ما ماذا متى مذ مع مما ممن من منه منها منذ مه مهما نحن نحو نعم ها هاتان هاته هاتي هاتين هاك هاهنا هذا هذان هذه هذي هذين هكذا هل هلا هم هما هن هنا 
# ...

# %% [markdown]
# Removing stop words

# %%
DataFrame2["Reviews"]=DataFrame2["Reviews"].apply(lambda x: [item for item in x if item not in stopwords_list])

# %% [markdown]
# Tweet text information

# %%
all_words = [word for tokens in DataFrame2["Reviews"] for word in tokens]
sentence_lengths = [len(tokens) for tokens in DataFrame2["Reviews"]]


print("%s words total" % (len(all_words)))
print("Max sentence length is %s" % max(sentence_lengths))
# Out:
# 4946 words total
# Max sentence length is 49
